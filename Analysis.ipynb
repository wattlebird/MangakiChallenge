# %%
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
import pandas as pd
import numpy as np

data = "/mnt/d/Data/mangaki-data-challenge/latest/"
import gc
gc.enable()

# %%
# for random forest

params = {
    'task': 'train',
    'boosting_type': 'rf',
    'objective': 'binary',
    'num_leaves': 550,
    'min_data_in_leaf': 6,
    'feature_fraction': 0.55,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'lambda_l1': 0,
    'min_gain_to_split': 0,
    'verbose': 0
}

def training(train, valid):
    X = lgb.Dataset(train.drop(['user_id', 'work_id', 'rating'], axis=1), train['rating'])
    gbdt = lgb.train(params, X, num_boost_round=116)
    Yvp = gbdt.predict(valid.drop(['user_id', 'work_id', 'rating'], axis=1))
    return Yvp

t = pd.read_csv(data+'train_1.csv')
v = pd.read_csv(data+'valid_1.csv')
t['item_category'] = t.item_category.astype('category')
v['item_category'] = v.item_category.astype('category')
pv = training(t, v)
f = v[['user_id', 'work_id', 'rating']].copy()
f['rf_prob'] = pv
f['rf_loss'] = -f.rating*np.log(pv)-(1.0-f.rating)*np.log(1-pv)
rf = f

# %%
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'num_leaves': 40,
    'min_data_in_leaf': 90,
    'feature_fraction': 0.6,
    'bagging_fraction': 0.96,
    'bagging_freq': 1,
    'lambda_l1': 0,
    'verbose': 0
}

def training(train, valid):
    X = lgb.Dataset(train.drop(['user_id', 'work_id', 'rating'], axis=1), train['rating'])
    gbdt = lgb.train(params, X, num_boost_round=119)
    Yvp = gbdt.predict(valid.drop(['user_id', 'work_id', 'rating'], axis=1))
    return Yvp

t = pd.read_csv(data+'train_1.csv')
v = pd.read_csv(data+'valid_1.csv')
t['item_category'] = t.item_category.astype('category')
v['item_category'] = v.item_category.astype('category')
pv = training(t, v)
f = v[['user_id', 'work_id', 'rating']].copy()
f['gbdt_prob'] = pv
f['gbdt_loss'] = -f.rating*np.log(pv)-(1.0-f.rating)*np.log(1-pv)
gbdt = f

# %%
from scipy.sparse import hstack
from fastFM import sgd
from sklearn.datasets import load_svmlight_file

libfmpath = "/mnt/d/Data/mangaki-data-challenge/libfm/"

params = {
    'n_iter':340000, 
    'init_stdev':0.01,
    'l2_reg_w':0.00025,
    'l2_reg_V':0.5,
    'rank':1,
    'step_size':0.02
}

def train_fm(train, valid, trainy):
    fm = sgd.FMClassification(**params)
    fm.fit(train, np.require(trainy*2-1, dtype=np.int))
    return fm.predict_proba(valid)

train, ty = load_svmlight_file(libfmpath+"train_1.csv")
valid, _ = load_svmlight_file(libfmpath+"valid_1.csv")
pv = train_fm(train, valid, ty)
v = pd.read_csv(data+'valid_1.csv')
f = v[['user_id', 'work_id', 'rating']].copy()
f['fm_prob'] = pv
f['fm_loss'] = -f.rating*np.log(pv)-(1.0-f.rating)*np.log(1-pv)
fm = f

# %%
pd.merge(gbdt, rf.drop('rating', axis=1), on=['user_id', 'work_id']).\
merge(fm.drop('rating', axis=1), on=['user_id', 'work_id']).to_csv('/mnt/d/Data/mangaki-data-challenge/analysis/analysis_full.csv', index=False)

# %%
# prepare metadata

data = "/mnt/d/Data/mangaki-data-challenge/"

record = pd.read_csv(data+'watched.csv', dtype={
    'user_id': np.int16,
    'work_id': np.int16,
    'rating': 'category'
})

title = pd.read_csv(data+'titles.csv', dtype={
    'work_id': np.int16,
    'title': str,
    'category': str
})

record = record.merge(title, on='work_id')

u1 = pd.crosstab(record[record.category=='anime'].user_id, record[record.category=='anime'].rating).add_prefix('user_anime_')
u2 = pd.crosstab(record[record.category=='manga'].user_id, record[record.category=='manga'].rating).add_prefix('user_manga_')

# %%
u3 = record.groupby(by='user_id')['work_id'].agg({'work_count': 'count'})
i1 = pd.crosstab(record.work_id, record.rating).add_prefix('work_')
i2 = record.groupby(by='work_id')['user_id'].agg({'user_count': 'count'})

# %%
record=record.merge(u1, left_on='user_id', right_index=True, how='left').merge(u2, left_on='user_id', right_index=True, how='left').\
merge(u3, left_on='user_id', right_index=True, how='left').merge(i1, left_on='work_id', right_index=True, how='left').\
merge(i2, left_on='work_id', right_index=True, how='left')

# %%
record.to_csv(data+"analysis/record.csv", index=False)

# %%
record
# Out:
#         user_id  work_id   rating  \
# 0           717     8025  dislike
# 1          1222     8025  dislike
# 2            40     8025  neutral
# 3          1563     8025  dislike
# 4            25     8025     like
# 5           248     8025     like
# 6          1967     8025     like
# 7           992     8025     like
# 8          1545     8025  neutral
# 9          1048     8025  neutral
# 10          313     8025  dislike
# 11          138     8025  dislike
# 12         1439     8025     like
# 13         1573     8025     like
# 14          617     8025  neutral
# 15         1868     8025  dislike
# 16         1503     8025     like
# 17         1624     8025     like
# 18          613     8025     like
# 19           32     8025  neutral
# 20          809     8025  neutral
# 21         1541     8025     like
# 22         1394     8025     like
# 23          961     8025  dislike
# 24          526     8025     like
# 25         1982     8025     like
# 26          448     8025  dislike
# 27         1508     8025  dislike
# 28          405     8025  neutral
# 29         1032     8025     like
# ...         ...      ...      ...
# 198940      199     2514  dislike
# 198941      220     3305     like
# 198942     1211     4249     like
# 198943     1743     1185  neutral
# 198944     1142     4047     like
# 198945      608     5130  dislike
# 198946      566      524  neutral
# 198947     1785     6143     like
# 198948      405     5147     like
# 198949      566     5147     like
# 198950      508     6111     like
# 198951     1781     2455     like
# 198952      872     4269  dislike
# 198953     1289     2321     like
# 198954     1128     1976     like
# 198955     1463     5492     like
# 198956     1601     2128  dislike
# 198957     1940     9765     like
# 198958      985     4202     like
# 198959     1886     6621     like
# 198960      199      162  dislike
# 198961      666     3029  neutral
# 198962     1268      255  neutral
# 198963     1938     3951  neutral
# 198964     1940     1560     like
# 198965     1940     6829     like
# 198966     1926     5513     like
# 198967     1221     2872  dislike
# 198968     1743     3425  neutral
# 198969      872     3306  dislike
#
#                                                     title category  \
# 0                                              Fairy Tail    anime
# 1                                              Fairy Tail    anime
# 2                                              Fairy Tail    anime
# 3                                              Fairy Tail    anime
# 4                                              Fairy Tail    anime
# 5                                              Fairy Tail    anime
# 6                                              Fairy Tail    anime
# 7                                              Fairy Tail    anime
# 8                                              Fairy Tail    anime
# 9                                              Fairy Tail    anime
# 10                                             Fairy Tail    anime
# 11                                             Fairy Tail    anime
# 12                                             Fairy Tail    anime
# 13                                             Fairy Tail    anime
# 14                                             Fairy Tail    anime
# 15                                             Fairy Tail    anime
# 16                                             Fairy Tail    anime
# 17                                             Fairy Tail    anime
# 18                                             Fairy Tail    anime
# 19                                             Fairy Tail    anime
# 20                                             Fairy Tail    anime
# 21                                             Fairy Tail    anime
# 22                                             Fairy Tail    anime
# 23                                             Fairy Tail    anime
# 24                                             Fairy Tail    anime
# 25                                             Fairy Tail    anime
# 26                                             Fairy Tail    anime
# 27                                             Fairy Tail    anime
# 28                                             Fairy Tail    anime
# 29                                             Fairy Tail    anime
# ...                                                   ...      ...
# 198940                 Shinkon Gattai Godannar 2nd Season    anime
# 198941                                 Tokyo Ghoul: Pinto    anime
# 198942                                      Sengoku Musou    anime
# 198943                                    The Ocean Waves    anime
# 198944                         HORIZON feat. Hatsune Miku    anime
# 198945                                       Platinum End    manga
# 198946                                Gunnm Other Stories    manga
# 198947                   Hakuouki Movie 2: Shikon Soukyuu    anime
# 198948                                            Dr Kotô    manga
# 198949                                            Dr Kotô    manga
# 198950                              Arslan Senki (TV) OVA    anime
# 198951                               Dimension W Specials    anime
# 198952                 The Erotic Adventures Of Tom Thumb    anime
# 198953        Little Witch Academia: The Enchanted Parade    anime
# 198954                            Senya Ichiya Monogatari    anime
# 198955                                    Saiyuki Gunlock    anime
# 198956  Kino no Tabi: Nanika wo Suru Tame ni - Life Go...    anime
# 198957                                               Line    manga
# 198958                                             Madara    manga
# 198959                                      Mars Daybreak    anime
# 198960                           Giant Robo Gaiden Ginrei    anime
# 198961                                  Rape! Rape! Rape!    anime
# 198962                                     Oh! Edo Rocket    anime
# 198963                                        Sex Pistols    anime
# 198964                                           Playback    manga
# 198965                         Genshiken Nidaime Specials    anime
# 198966                   Monju - Au service de la justice    manga
# 198967                          Pokemon XY: Sora no Hahen    anime
# 198968             Dragon Ball Movie 4: The Path to Power    anime
# 198969                           The Cosmopolitan Prayers    anime
#
#         user_anime_dislike  user_anime_like  user_anime_love  \
# 0                      2.0             10.0             17.0
# 1                      9.0             44.0              0.0
# 2                      3.0             40.0             64.0
# 3                     26.0            319.0              0.0
# 4                      0.0             19.0              0.0
# 5                     28.0             36.0              0.0
# 6                      2.0             23.0              0.0
# 7                      2.0             40.0              0.0
# 8                      0.0             78.0              0.0
# 9                     21.0            101.0             15.0
# 10                     7.0             42.0              0.0
# 11                     3.0             22.0              8.0
# 12                     0.0             16.0              0.0
# 13                     2.0             72.0              7.0
# 14                     1.0             30.0              0.0
# 15                     8.0             18.0              0.0
# 16                     3.0            145.0              0.0
# 17                     2.0             69.0              0.0
# 18                     1.0             87.0              0.0
# 19                    13.0             82.0              0.0
# 20                     0.0             52.0              0.0
# 21                    11.0            485.0              0.0
# 22                     0.0             58.0              0.0
# 23                     5.0             55.0              9.0
# 24                    50.0            122.0             24.0
# 25                     5.0             14.0              0.0
# 26                     5.0             64.0             27.0
# 27                    12.0             34.0              3.0
# 28                     5.0             46.0              0.0
# 29                     0.0             17.0             31.0
# ...                    ...              ...              ...
# 198940               186.0            159.0              0.0
# 198941                 0.0              4.0              8.0
# 198942                 2.0            467.0              0.0
# 198943               136.0            333.0             39.0
# 198944                52.0            197.0             54.0
# 198945                58.0             49.0              3.0
# 198946                 NaN              NaN              NaN
# 198947                 3.0             29.0              0.0
# 198948                 5.0             46.0              0.0
# 198949                 NaN              NaN              NaN
# 198950                51.0            227.0             18.0
# 198951                18.0            522.0              0.0
# 198952               137.0            294.0              0.0
# 198953                 0.0             31.0              2.0
# 198954                12.0            216.0              0.0
# 198955                90.0            332.0              0.0
# 198956                 3.0             11.0              8.0
# 198957                61.0            625.0             52.0
# 198958                 0.0              1.0              0.0
# 198959                 0.0            107.0             17.0
# 198960               186.0            159.0              0.0
# 198961                 0.0            184.0              0.0
# 198962                88.0            259.0              0.0
# 198963                10.0             45.0              0.0
# 198964                61.0            625.0             52.0
# 198965                61.0            625.0             52.0
# 198966                 9.0             58.0             18.0
# 198967                95.0            365.0              0.0
# 198968               136.0            333.0             39.0
# 198969               137.0            294.0              0.0
#
#         user_anime_neutral  user_manga_dislike  user_manga_like  \
# 0                     16.0                 NaN              NaN
# 1                     12.0                 NaN              NaN
# 2                     14.0                 0.0              1.0
# 3                     71.0                13.0             83.0
# 4                      0.0                 0.0              9.0
# 5                     10.0                 0.0              3.0
# 6                      1.0                 2.0             12.0
# 7                      4.0                 0.0              3.0
# 8                      4.0                 0.0              4.0
# 9                     61.0                31.0            122.0
# 10                     0.0                 1.0             12.0
# 11                     1.0                 1.0             22.0
# 12                     1.0                 2.0             13.0
# 13                     8.0                 NaN              NaN
# 14                     5.0                 NaN              NaN
# 15                     6.0                21.0             47.0
# 16                     9.0                 NaN              NaN
# 17                     2.0                 NaN              NaN
# 18                     5.0                 NaN              NaN
# 19                    39.0                13.0             62.0
# 20                    12.0                 NaN              NaN
# 21                   172.0                 NaN              NaN
# 22                     0.0                 3.0             23.0
# 23                    12.0                12.0             56.0
# 24                    87.0                 NaN              NaN
# 25                     2.0                 0.0             10.0
# 26                    23.0                 1.0             29.0
# 27                    21.0                 0.0              1.0
# 28                    11.0                14.0             79.0
# 29                     4.0                 0.0              8.0
# ...                    ...                 ...              ...
# 198940               255.0                 1.0             20.0
# 198941                 0.0                 NaN              NaN
# 198942                43.0                 0.0             17.0
# 198943               125.0                 0.0              7.0
# 198944               148.0                 2.0              4.0
# 198945                13.0                 6.0              6.0
# 198946                 NaN               131.0            224.0
# 198947                 5.0                 0.0              7.0
# 198948                11.0                14.0             79.0
# 198949                 NaN               131.0            224.0
# 198950               114.0                 5.0             41.0
# 198951                91.0                 NaN              NaN
# 198952               174.0                 NaN              NaN
# 198953                 5.0                 0.0              1.0
# 198954                49.0                 NaN              NaN
# 198955               126.0                12.0             49.0
# 198956                 5.0                 1.0              7.0
# 198957               184.0                28.0            193.0
# 198958                 0.0                17.0            228.0
# 198959                17.0                 1.0              1.0
# 198960               255.0                 1.0             20.0
# 198961                29.0                 NaN              NaN
# 198962                88.0                 NaN              NaN
# 198963                35.0                 2.0             39.0
# 198964               184.0                28.0            193.0
# 198965               184.0                28.0            193.0
# 198966                19.0                 1.0             52.0
# 198967                31.0                 7.0             36.0
# 198968               125.0                 0.0              7.0
# 198969               174.0                 NaN              NaN
#
#         user_manga_love  user_manga_neutral  work_count  work_dislike  \
# 0                   NaN                 NaN          45           226
# 1                   NaN                 NaN          65           226
# 2                   8.0                 0.0         130           226
# 3                   0.0                20.0         532           226
# 4                   0.0                 0.0          28           226
# 5                   0.0                 0.0          77           226
# 6                   0.0                 0.0          40           226
# 7                   0.0                 0.0          49           226
# 8                   0.0                 0.0          86           226
# 9                   4.0                31.0         386           226
# 10                  0.0                 0.0          62           226
# 11                  2.0                 2.0          61           226
# 12                  0.0                 3.0          35           226
# 13                  NaN                 NaN          89           226
# 14                  NaN                 NaN          36           226
# 15                  0.0                 8.0         108           226
# 16                  NaN                 NaN         157           226
# 17                  NaN                 NaN          73           226
# 18                  NaN                 NaN          93           226
# 19                  0.0                 8.0         217           226
# 20                  NaN                 NaN          64           226
# 21                  NaN                 NaN         668           226
# 22                  0.0                 0.0          84           226
# 23                 11.0                28.0         188           226
# 24                  NaN                 NaN         283           226
# 25                  0.0                 0.0          31           226
# 26                 20.0                12.0         181           226
# 27                  0.0                 0.0          71           226
# 28                  0.0                43.0         198           226
# 29                 17.0                15.0          92           226
# ...                 ...                 ...         ...           ...
# 198940              0.0                 5.0         626             1
# 198941              NaN                 NaN          12             0
# 198942              0.0                 0.0         529             0
# 198943              0.0                 0.0         640             0
# 198944              2.0                 4.0         463             0
# 198945              0.0                 1.0         136             1
# 198946              0.0               183.0         538             0
# 198947              0.0                 0.0          44             0
# 198948              0.0                43.0         198             0
# 198949              0.0               183.0         538             0
# 198950              5.0                14.0         475             0
# 198951              NaN                 NaN         631             0
# 198952              NaN                 NaN         605             1
# 198953              0.0                 0.0          39             0
# 198954              NaN                 NaN         277             0
# 198955              0.0                11.0         620             0
# 198956              6.0                 0.0          41             1
# 198957             25.0               111.0        1279             0
# 198958              0.0                47.0         293             0
# 198959              0.0                 2.0         145             0
# 198960              0.0                 5.0         626             1
# 198961              NaN                 NaN         213             0
# 198962              NaN                 NaN         435             0
# 198963              0.0                11.0         142             0
# 198964             25.0               111.0        1279             0
# 198965             25.0               111.0        1279             0
# 198966              2.0                 3.0         162             0
# 198967              0.0                 0.0         534             1
# 198968              0.0                 0.0         640             0
# 198969              NaN                 NaN         605             1
#
#         work_like  work_love  work_neutral  user_count
# 0             429         43           242         940
# 1             429         43           242         940
# 2             429         43           242         940
# 3             429         43           242         940
# 4             429         43           242         940
# 5             429         43           242         940
# 6             429         43           242         940
# 7             429         43           242         940
# 8             429         43           242         940
# 9             429         43           242         940
# 10            429         43           242         940
# 11            429         43           242         940
# 12            429         43           242         940
# 13            429         43           242         940
# 14            429         43           242         940
# 15            429         43           242         940
# 16            429         43           242         940
# 17            429         43           242         940
# 18            429         43           242         940
# 19            429         43           242         940
# 20            429         43           242         940
# 21            429         43           242         940
# 22            429         43           242         940
# 23            429         43           242         940
# 24            429         43           242         940
# 25            429         43           242         940
# 26            429         43           242         940
# 27            429         43           242         940
# 28            429         43           242         940
# 29            429         43           242         940
# ...           ...        ...           ...         ...
# 198940          0          0             0           1
# 198941          1          0             0           1
# 198942          1          0             0           1
# 198943          0          0             1           1
# 198944          1          0             0           1
# 198945          0          0             0           1
# 198946          0          0             1           1
# 198947          1          0             0           1
# 198948          2          0             0           2
# 198949          2          0             0           2
# 198950          1          0             0           1
# 198951          1          0             0           1
# 198952          0          0             0           1
# 198953          1          0             0           1
# 198954          1          0             0           1
# 198955          1          0             0           1
# 198956          0          0             0           1
# 198957          1          0             0           1
# 198958          1          0             0           1
# 198959          1          0             0           1
# 198960          0          0             0           1
# 198961          0          0             1           1
# 198962          0          0             1           1
# 198963          0          0             1           1
# 198964          1          0             0           1
# 198965          1          0             0           1
# 198966          1          0             0           1
# 198967          0          0             0           1
# 198968          0          0             1           1
# 198969          0          0             0           1
#
# [198970 rows x 19 columns]
